# %%
# %pip install lazypredict
# Out:
# Requirement already satisfied: lazypredict in /Users/caferkosker/opt/anaconda3/lib/python3.9/site-packages (0.3.0)
# Requirement already satisfied: click in /Users/caferkosker/opt/anaconda3/lib/python3.9/site-packages (from lazypredict) (8.0.4)
# Requirement already satisfied: scikit-learn>=1.0 in /Users/caferkosker/opt/anaconda3/lib/python3.9/site-packages (from lazypredict) (1.2.2)
# Requirement already satisfied: pandas>=1.3 in /Users/caferkosker/opt/anaconda3/lib/python3.9/site-packages (from lazypredict) (1.4.4)
# Requirement already satisfied: tqdm>=4.0 in /Users/caferkosker/opt/anaconda3/lib/python3.9/site-packages (from lazypredict) (4.64.1)
# Requirement already satisfied: joblib>=1.0 in /Users/caferkosker/opt/anaconda3/lib/python3.9/site-packages (from lazypredict) (1.5.3)
# Requirement already satisfied: numpy>=1.21 in /Users/caferkosker/opt/anaconda3/lib/python3.9/site-packages (from lazypredict) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/caferkosker/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.3->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/caferkosker/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.3->lazypredict) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/caferkosker/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.3->lazypredict) (1.16.0)
# Requirement already satisfied: scipy>=1.3.2 in /Users/caferkosker/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=1.0->lazypredict) (1.9.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/caferkosker/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=1.0->lazypredict) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np

# %%
import sys

print(sys.executable)
print(sys.version)
# Out:
# /Users/caferkosker/opt/anaconda3/bin/python
# 3.9.13 (main, Aug 25 2022, 18:29:29)
# [Clang 12.0.0 ]

# %%
import sklearn

print(sklearn.__version__)
# Out:
# 1.2.2

# %%
# %pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Users/caferkosker/opt/anaconda3/lib/python3.9/site-packages (1.2.2)
# Collecting scikit-learn
#   Using cached scikit_learn-1.6.1-cp39-cp39-macosx_10_9_x86_64.whl.metadata (31 kB)
# Requirement already satisfied: numpy>=1.19.5 in /Users/caferkosker/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.21.6)
# Requirement already satisfied: scipy>=1.6.0 in /Users/caferkosker/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/caferkosker/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/caferkosker/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (3.6.0)
# Using cached scikit_learn-1.6.1-cp39-cp39-macosx_10_9_x86_64.whl (12.1 MB)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# Successfully installed scikit-learn-1.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np

# %%
diabetes  = datasets.load_diabetes()

# %%
X, y = shuffle(diabetes.data, diabetes.target, random_state=13)
X = X.astype(np.float32)

offset = int(X.shape[0] * 0.9)

X_train, y_train = X[:offset], y[:offset]
X_test, y_test = X[offset:], y[offset:]

reg = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
#                                Adjusted R-Squared  R-Squared        RMSE  \
# Model
# ExtraTreesRegressor                      0.378921   0.520076   54.220181
# OrthogonalMatchingPursuitCV              0.374947   0.517004   54.393394
# Lasso                                    0.373483   0.515873   54.457049
# LassoLars                                0.373474   0.515866   54.457449
# LarsCV                                   0.371500   0.514341   54.543153
# LassoCV                                  0.370413   0.513501   54.590299
# PassiveAggressiveRegressor               0.366958   0.510831   54.739888
# LassoLarsIC                              0.364985   0.509306   54.825141
# SGDRegressor                             0.364308   0.508783   54.854357
# Ridge                                    0.363002   0.507774   54.910654
# RidgeCV                                  0.363002   0.507774   54.910673
# BayesianRidge                            0.362296   0.507229   54.941071
# LassoLarsCV                              0.361750   0.506807   54.964620
# TransformedTargetRegressor               0.361749   0.506806   54.964652
# LinearRegression                         0.361749   0.506806   54.964652
# Lars                                     0.358828   0.504549   55.090294
# ElasticNetCV                             0.356159   0.502486   55.204825
# HuberRegressor                           0.355251   0.501785   55.243742
# RandomForestRegressor                    0.349621   0.497434   55.484423
# AdaBoostRegressor                        0.340416   0.490322   55.875662
# HistGradientBoostingRegressor            0.335632   0.486625   56.077921
# PoissonRegressor                         0.323033   0.476889   56.607187
# ElasticNet                               0.301755   0.460447   57.489920
# KNeighborsRegressor                      0.299855   0.458979   57.568054
# OrthogonalMatchingPursuit                0.292421   0.453234   57.872883
# BaggingRegressor                         0.291213   0.452301   57.922287
# GradientBoostingRegressor                0.247009   0.418143   59.701142
# TweedieRegressor                         0.244215   0.415984   59.811792
# GammaRegressor                           0.223895   0.400283   60.610504
# RANSACRegressor                          0.203535   0.384550   61.400384
# LinearSVR                                0.116707   0.317455   64.660656
# ExtraTreeRegressor                       0.002019   0.228833   68.730391
# NuSVR                                   -0.066704   0.175728   71.057466
# SVR                                     -0.096413   0.152772   72.040169
# DummyRegressor                          -0.297553  -0.002655   78.370078
# QuantileRegressor                       -0.346561  -0.040525   79.836360
# DecisionTreeRegressor                   -0.470263  -0.136112   83.422885
# GaussianProcessRegressor                -0.769174  -0.367089   91.510930
# MLPRegressor                            -1.867720  -1.215965  116.508077
# KernelRidge                             -5.038148  -3.665841  169.059486
#
#                                Time Taken
# Model
# ExtraTreesRegressor              0.122112
# OrthogonalMatchingPursuitCV      0.007129
# Lasso                            0.004421
# LassoLars                        0.005344
# LarsCV                           0.010643
# LassoCV                          0.041629
# PassiveAggressiveRegressor       0.005038
# LassoLarsIC                      0.006615
# SGDRegressor                     0.004729
# Ridge                            0.004244
# RidgeCV                          0.004500
# BayesianRidge                    0.006007
# LassoLarsCV                      0.012494
# TransformedTargetRegressor       0.005245
# LinearRegression                 0.004753
# Lars                             0.005157
# ElasticNetCV                     0.033584
# HuberRegressor                   0.008571
# RandomForestRegressor            0.183457
# AdaBoostRegressor                0.059756
# HistGradientBoostingRegressor    0.397745
# PoissonRegressor                 0.011513
# ElasticNet                       0.004888
# KNeighborsRegressor              0.004757
# OrthogonalMatchingPursuit        0.004475
# BaggingRegressor                 0.027119
# GradientBoostingRegressor        0.072046
# TweedieRegressor                 0.006033
# GammaRegressor                   0.006230
# RANSACRegressor                  0.058924
# LinearSVR                        0.004205
# ExtraTreeRegressor               0.005509
# NuSVR                            0.013200
# SVR                              0.015829
# DummyRegressor                   0.004057
# QuantileRegressor                1.870044
# DecisionTreeRegressor            0.006677
# GaussianProcessRegressor         0.011551
# MLPRegressor                     0.180646
# KernelRidge                      0.006405
