# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("diamonds.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  str
#  3   color       53940 non-null  str
#  4   clarity     53940 non-null  str
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), str(3)
# memory usage: 5.1 MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
df = df.drop("Unnamed: 0", axis=1)

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df["color"].unique()
# Out:
# <ArrowStringArray>
# ['E', 'I', 'J', 'H', 'F', 'G', 'D']
# Length: 7, dtype: str

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %%
len(df[df["z"] == 0]),len(df[df["x"] == 0]),len(df[df["y"] == 0])
# Out:
# (20, 8, 7)

# %%
df = df.drop(df[df["z"] == 0].index)
df = df.drop(df[df["x"] == 0].index)
df = df.drop(df[df["y"] == 0].index)

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53920.000000  53920.000000  53920.000000  53920.000000  53920.000000
# mean       0.797698     61.749514     57.456834   3930.993231      5.731627
# std        0.473795      1.432331      2.234064   3987.280446      1.119423
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5323.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53920.000000  53920.000000
# mean       5.734887      3.540046
# std        1.140126      0.702530
# min        3.680000      1.070000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %%
sns.scatterplot(x=df["depth"],y=df["carat"],hue=df["price"])
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
df = df[(df["depth"]<75)&(df["depth"]>45)]
df = df[(df["table"]<80)&(df["table"]>40)]
df = df[(df["y"]<30)]
df = df[(df["z"]<30)&(df["z"]>2)]

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53907.000000  53907.000000  53907.000000  53907.000000  53907.000000
# mean       0.797628     61.749741     57.455948   3930.584470      5.731463
# std        0.473765      1.420119      2.226153   3987.202815      1.119384
# min        0.200000     50.800000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5322.000000      6.540000
# max        5.010000     73.600000     79.000000  18823.000000     10.740000
#
#                   y             z
# count  53907.000000  53907.000000
# mean       5.733292      3.539441
# std        1.111252      0.691434
# min        3.680000      2.060000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       10.540000      6.980000

# %%
sns.scatterplot(x=df["z"], y=df["price"])
plt.show()

# %%
sns.scatterplot(x=df["y"], y=df["price"])
plt.show()

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df["cut"].value_counts()
# Out:
# cut
# Ideal        21543
# Premium      13779
# Very Good    12080
# Good          4902
# Fair          1603
# Name: count, dtype: int64

# %%
df["color"].value_counts()
# Out:
# color
# G    11282
# E     9792
# F     9536
# H     8296
# D     6774
# I     5420
# J     2807
# Name: count, dtype: int64

# %%
df["clarity"].value_counts()
# Out:
# clarity
# SI1     13059
# VS2     12250
# SI2      9184
# VS1      8167
# VVS2     5066
# VVS1     3654
# IF       1790
# I1        737
# Name: count, dtype: int64

# %%
X = df.drop("price",axis=1)
y = df["price"]

# %%
X.head()
# Out:
#    carat      cut color clarity  depth  table     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  4.34  4.35  2.75

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=15)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
for col in ["cut","color","clarity"]:
    X_train[col] = label_encoder.fit_transform(X_train[col])
    X_test[col] = label_encoder.transform(X_test[col])

# %%
X_train.head()
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z
# 15200   1.15    2      4        2   62.4   54.0  6.71  6.76  4.20
# 14632   1.11    3      1        2   61.3   58.0  6.66  6.61  4.07
# 19151   1.21    1      2        5   63.7   58.0  6.67  6.71  4.26
# 29299   0.30    2      5        5   61.5   58.0  4.28  4.31  2.64
# 9983    1.00    4      2        2   63.1   57.0  6.37  6.33  4.01

# %%
 X_train["color"].value_counts()
# Out:
# color
# 3    8449
# 1    7363
# 2    7173
# 4    6158
# 0    5071
# 5    4105
# 6    2111
# Name: count, dtype: int64

# %%
X_train.describe()
# Out:
#               carat           cut         color       clarity         depth  \
# count  40430.000000  40430.000000  40430.000000  40430.000000  40430.000000
# mean       0.796206      2.552708      2.594089      3.840861     61.753396
# std        0.474132      1.025958      1.702470      1.724057      1.411827
# min        0.200000      0.000000      0.000000      0.000000     52.200000
# 25%        0.400000      2.000000      1.000000      2.000000     61.100000
# 50%        0.700000      2.000000      3.000000      4.000000     61.800000
# 75%        1.040000      3.000000      4.000000      5.000000     62.500000
# max        5.010000      4.000000      6.000000      7.000000     72.200000
#
#               table             x             y             z
# count  40430.000000  40430.000000  40430.000000  40430.000000
# mean      57.448897      5.727667      5.729408      3.537283
# std        2.221713      1.119875      1.111668      0.691941
# min       43.000000      3.730000      3.710000      2.060000
# 25%       56.000000      4.710000      4.720000      2.910000
# 50%       57.000000      5.690000      5.700000      3.520000
# 75%       59.000000      6.540000      6.530000      4.030000
# max       73.000000     10.740000     10.540000      6.980000

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
linear = LinearRegression()
linear.fit(X_train_scaled,y_train)
y_pred = linear.predict(X_test_scaled)
mae = mean_absolute_error(y_pred,y_test)
mse = mean_squared_error(y_pred,y_test)
score = r2_score(y_pred,y_test)
print("Mean Absolute Error: ",mae)
print("Mean Squared Error: ",mse)
print("R2 Score: ",score)
plt.scatter(y_test,y_pred)
plt.show()
# Out:
# Mean Absolute Error:  864.5945387870884
# Mean Squared Error:  1847631.3774594294
# R2 Score:  0.8691649996261415

# %%
from sklearn.svm import SVR

# %%
svr = SVR()
svr.fit(X_train_scaled,y_train)
y_pred = svr.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
score = r2_score(y_test,y_pred)
print("Mean Absolute Error: ",mae)
print("Mean Squared Error: ",mse)
print("R2 Score: ",score)
plt.scatter(y_test,y_pred)
plt.show()
# Out:
# Mean Absolute Error:  1398.2632905135665
# Mean Squared Error:  8155498.032883635
# R2 Score:  0.49245884122391603

# %%
#hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    "C" : [0.1,1,10,100,1000],
    "kernel" : ["rbf","linear"],
    "gamma" : ["scale","auto"]  
}

# %%
grid = GridSearchCV(estimator=SVR(),param_grid=param_grid,n_jobs=-1,verbose=3)

# %%
grid.fit(X_train_scaled,y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['rbf', 'linear']},
#              verbose=3)
# [CV 4/5] END ...C=0.1, gamma=scale, kernel=rbf;, score=-0.028 total time=  58.9s
# [CV 1/5] END ..C=0.1, gamma=auto, kernel=linear;, score=0.722 total time=  45.1s
# [CV 3/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.445 total time=  58.9s
# [CV 3/5] END ....C=1, gamma=auto, kernel=linear;, score=0.828 total time=  41.0s
# [CV 1/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.840 total time=  52.9s
# [CV 1/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.840 total time=  52.4s
# [CV 2/5] END ....C=100, gamma=scale, kernel=rbf;, score=0.928 total time=  51.1s
# [CV 1/5] END .....C=100, gamma=auto, kernel=rbf;, score=0.930 total time=  52.6s
# [CV 1/5] END ...C=1000, gamma=scale, kernel=rbf;, score=0.946 total time= 1.0min
# [CV 1/5] END ....C=1000, gamma=auto, kernel=rbf;, score=0.946 total time= 1.0min
# [CV 5/5] END ...C=0.1, gamma=scale, kernel=rbf;, score=-0.029 total time= 1.0min
# [CV 3/5] END ..C=0.1, gamma=auto, kernel=linear;, score=0.711 total time=  45.1s
# [CV 2/5] END ...C=1, gamma=scale, kernel=linear;, score=0.835 total time=  47.6s
# [CV 1/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.451 total time= 1.1min
# [CV 4/5] END ..C=10, gamma=scale, kernel=linear;, score=0.868 total time=  45.7s
# [CV 1/5] END ...C=10, gamma=auto, kernel=linear;, score=0.877 total time=  45.8s
# [CV 1/5] END ....C=100, gamma=scale, kernel=rbf;, score=0.930 total time=  52.0s
# [CV 2/5] END .....C=100, gamma=auto, kernel=rbf;, score=0.928 total time=  53.3s
# [CV 2/5] END ...C=1000, gamma=scale, kernel=rbf;, score=0.942 total time= 1.0min
# [CV 2/5] END ....C=1000, gamma=auto, kernel=rbf;, score=0.942 total time= 1.0min
# [CV 3/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.711 total time=  45.3s
# [CV 5/5] END ....C=0.1, gamma=auto, kernel=rbf;, score=-0.029 total time=  59.3s
# [CV 1/5] END ...C=1, gamma=scale, kernel=linear;, score=0.840 total time=  48.4s
# [CV 2/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.451 total time= 1.0min
# [CV 1/5] END ..C=10, gamma=scale, kernel=linear;, score=0.877 total time=  45.6s
# [CV 3/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.838 total time=  52.7s
# [CV 2/5] END .C=100, gamma=scale, kernel=linear;, score=0.874 total time=  50.5s
# [CV 3/5] END .....C=100, gamma=auto, kernel=rbf;, score=0.925 total time=  55.2s
# [CV 3/5] END ...C=1000, gamma=scale, kernel=rbf;, score=0.940 total time= 1.0min
# [CV 3/5] END ....C=1000, gamma=auto, kernel=rbf;, score=0.940 total time= 1.0min
# [CV 2/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.718 total time=  45.1s
# [CV 4/5] END ....C=0.1, gamma=auto, kernel=rbf;, score=-0.028 total time=  58.8s
# [CV 2/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.451 total time=  58.9s
# [CV 1/5] END ....C=1, gamma=auto, kernel=linear;, score=0.840 total time=  51.6s
# [CV 4/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.854 total time=  52.8s
# [CV 3/5] END ...C=10, gamma=auto, kernel=linear;, score=0.863 total time=  45.9s
# [CV 4/5] END ....C=100, gamma=scale, kernel=rbf;, score=0.933 total time=  51.3s
# [CV 4/5] END .....C=100, gamma=auto, kernel=rbf;, score=0.933 total time=  56.1s
# [CV 4/5] END ...C=1000, gamma=scale, kernel=rbf;, score=0.946 total time=  59.8s
# [CV 4/5] END ....C=1000, gamma=auto, kernel=rbf;, score=0.946 total time= 1.0min
# [CV 1/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.722 total time=  44.1s
# [CV 1/5] END ....C=0.1, gamma=auto, kernel=rbf;, score=-0.017 total time=  59.4s
# [CV 1/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.450 total time=  59.3s
# [CV 2/5] END ....C=1, gamma=auto, kernel=linear;, score=0.835 total time=  51.3s
# [CV 3/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.838 total time=  53.5s
# [CV 5/5] END ...C=10, gamma=auto, kernel=linear;, score=0.871 total time=  45.9s
# [CV 5/5] END ....C=100, gamma=scale, kernel=rbf;, score=0.931 total time=  51.4s
# [CV 2/5] END ..C=100, gamma=auto, kernel=linear;, score=0.874 total time=  56.0s
# [CV 5/5] END ...C=1000, gamma=scale, kernel=rbf;, score=0.943 total time= 1.0min
# [CV 5/5] END ....C=1000, gamma=auto, kernel=rbf;, score=0.943 total time= 1.0min
# [CV 1/5] END ...C=0.1, gamma=scale, kernel=rbf;, score=-0.017 total time= 1.0min
# [CV 4/5] END ..C=0.1, gamma=auto, kernel=linear;, score=0.717 total time=  45.8s
# [CV 4/5] END ...C=1, gamma=scale, kernel=linear;, score=0.833 total time=  47.7s
# [CV 4/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.464 total time= 1.1min
# [CV 5/5] END ..C=10, gamma=scale, kernel=linear;, score=0.871 total time=  45.3s
# [CV 5/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.851 total time=  54.3s
# [CV 5/5] END .C=100, gamma=scale, kernel=linear;, score=0.873 total time=  51.0s
# [CV 5/5] END ..C=100, gamma=auto, kernel=linear;, score=0.873 total time=  53.6s
# [CV 2/5] END C=1000, gamma=scale, kernel=linear;, score=0.875 total time= 1.6min
# [CV 1/5] END .C=1000, gamma=auto, kernel=linear;, score=0.879 total time= 1.5min
# [CV 5/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.716 total time=  44.7s
# [CV 3/5] END ....C=0.1, gamma=auto, kernel=rbf;, score=-0.028 total time=  59.7s
# [CV 5/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.452 total time=  59.7s
# [CV 5/5] END ....C=1, gamma=auto, kernel=linear;, score=0.834 total time=  51.5s
# [CV 2/5] END ..C=10, gamma=scale, kernel=linear;, score=0.872 total time=  45.0s
# [CV 2/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.841 total time=  54.7s
# [CV 4/5] END .C=100, gamma=scale, kernel=linear;, score=0.869 total time=  51.3s
# [CV 4/5] END ..C=100, gamma=auto, kernel=linear;, score=0.869 total time=  56.0s
# [CV 4/5] END C=1000, gamma=scale, kernel=linear;, score=0.869 total time= 1.6min
# [CV 2/5] END .C=1000, gamma=auto, kernel=linear;, score=0.875 total time= 1.5min
# [CV 4/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.717 total time=  44.6s
# [CV 2/5] END ....C=0.1, gamma=auto, kernel=rbf;, score=-0.014 total time=  59.9s
# [CV 4/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.465 total time=  58.8s
# [CV 4/5] END ....C=1, gamma=auto, kernel=linear;, score=0.833 total time=  51.3s
# [CV 5/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.851 total time=  52.7s
# [CV 4/5] END ...C=10, gamma=auto, kernel=linear;, score=0.868 total time=  46.3s
# [CV 1/5] END .C=100, gamma=scale, kernel=linear;, score=0.879 total time=  51.2s
# [CV 1/5] END ..C=100, gamma=auto, kernel=linear;, score=0.879 total time=  56.5s
# [CV 1/5] END C=1000, gamma=scale, kernel=linear;, score=0.879 total time= 1.7min
# [CV 3/5] END .C=1000, gamma=auto, kernel=linear;, score=0.864 total time= 1.4min
# [CV 2/5] END ...C=0.1, gamma=scale, kernel=rbf;, score=-0.014 total time=  59.7s
# [CV 2/5] END ..C=0.1, gamma=auto, kernel=linear;, score=0.718 total time=  46.1s
# [CV 3/5] END ...C=1, gamma=scale, kernel=linear;, score=0.828 total time=  47.3s
# [CV 3/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.445 total time= 1.0min
# [CV 3/5] END ..C=10, gamma=scale, kernel=linear;, score=0.863 total time=  45.6s
# [CV 4/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.853 total time=  53.5s
# [CV 3/5] END .C=100, gamma=scale, kernel=linear;, score=0.864 total time=  51.2s
# [CV 3/5] END ..C=100, gamma=auto, kernel=linear;, score=0.864 total time=  55.7s
# [CV 3/5] END C=1000, gamma=scale, kernel=linear;, score=0.864 total time= 1.7min
# [CV 4/5] END .C=1000, gamma=auto, kernel=linear;, score=0.869 total time= 1.4min
# [CV 3/5] END ...C=0.1, gamma=scale, kernel=rbf;, score=-0.028 total time= 1.0min
# [CV 5/5] END ..C=0.1, gamma=auto, kernel=linear;, score=0.716 total time=  44.9s
# [CV 5/5] END ...C=1, gamma=scale, kernel=linear;, score=0.834 total time=  47.9s
# [CV 5/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.452 total time=  55.0s
# [CV 2/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.841 total time=  55.4s
# [CV 2/5] END ...C=10, gamma=auto, kernel=linear;, score=0.872 total time=  45.7s
# [CV 3/5] END ....C=100, gamma=scale, kernel=rbf;, score=0.925 total time=  53.7s
# [CV 5/5] END .....C=100, gamma=auto, kernel=rbf;, score=0.931 total time=  59.1s
# [CV 5/5] END C=1000, gamma=scale, kernel=linear;, score=0.874 total time= 1.7min
# [CV 5/5] END .C=1000, gamma=auto, kernel=linear;, score=0.874 total time= 1.4min

# %%
grid.best_params_
# Out:
# {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}

# %%
y_pred  = grid.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
score = r2_score(y_test,y_pred)
print("Mean Absolute Error: ",mae)
print("Mean Squared Error: ",mse)
print("R2 Score: ",score)
plt.scatter(y_test,y_pred)
plt.show()
# Out:
# Mean Absolute Error:  478.3924525981736
# Mean Squared Error:  872242.8008942652
# R2 Score:  0.9457177084569239
